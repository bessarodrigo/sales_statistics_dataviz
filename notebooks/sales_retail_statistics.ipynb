# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

DADOS = r"C:\Users\rodri\OneDrive\Sincronização\Documentos\GitHub\sales_statistics_dataviz\dados\retail_sales_dataset.csv"

df_vendas = pd.read_csv(DADOS)

df_vendas.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df_vendas.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
from composicao_histograma_boxplot import composicao_histograma_boxplot

composicao_histograma_boxplot(df_vendas, "Total Amount", titulo="Distribuição do Faturamento Total")

# %%
from composicao_histograma_boxplot import calcular_estatisticas

# Aplicar a função
estatisticas_df_valor = calcular_estatisticas(df_vendas['Total Amount'].to_numpy())

# Exibir as estatísticas
print("Estatísticas para a coluna 'valor' do DataFrame:")
for chave, valor in estatisticas_df_valor.items():
    print(f"{chave}: {valor:.2f}")
# Out:
# Estatísticas para a coluna 'valor' do DataFrame:
# Média: 456.00
# Mediana: 135.00
# Moda: 50.00
# Variância: 313597.35
# Desvio Padrão: 560.00
# Assimetria: 1.37
# Curtose: 3.80
# 1º Quartil: 60.00
# 2º Quartil (Mediana): 135.00
# 3º Quartil: 900.00
